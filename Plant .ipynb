# %% [markdown]
# # New Section

# %%
import math
y=0
STOP = False
while not STOP:
  inpu=(int(input("enter a value:")))
  if(inpu%3==0):
    if(inpu>3):
      residue=inpu//3
      y=math.log2(residue)
      if(y-int(y)==0.0):
        print("It will take",int(y),"years for the bamboo tree to reach height of",inpu,"feet")		
      else:
        print("Invalid Input")
    elif(inpu==3):	
      print("The initial height of the plant is 3 feet")
    carryOn = input("carry on? y or n: ")
    if carryOn != "y":
     STOP = True
     print("Game over,Sayonara")
  else:
    print("invalid")
# Out:
# enter a value:9
# Invalid Input
# carry on? y or n: n
# Game over,Sayonara

# %%
import random

a=random.randint(1,10)

print("Secret number generated")

print("Guess a number between 1 and 10")
STOP = False
while not STOP:
	answer=int(input("Enter here: "))
	if answer==a:
		print("Hurray!! Lucky guess")
	elif answer>a:
		print("Oh snap !!Your input is greater than the secret number") 
	elif answer<a:
		print("Oh snap!!Your input is lesser than the secret number")
		
	carryOn = input("carry on? y or n: ")
	if carryOn != "y":
		STOP = True
		print("Game over,Sayonara")
# Out:
# Secret number generated
# Guess a number between 1 and 10
# Enter here: 8
# Oh snap!!Your input is lesser than the secret number
# carry on? y or n: y
# Enter here: 9
# Hurray!! Lucky guess
# carry on? y or n: n
# Game over,Sayonara
